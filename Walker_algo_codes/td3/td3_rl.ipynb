# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
import time
import gym
import numpy as np

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class ReplayBuffer:
    def __init__(self, max_size=5e5):
        self.buffer = []
        self.max_size = int(max_size)
        self.size = 0
    
    def add(self, transition):
        self.size +=1
        # transiton is tuple of (state, action, reward, next_state, done)
        self.buffer.append(transition)
    
    def sample(self, batch_size):
        # delete 1/5th of the buffer when full
        if self.size > self.max_size:
            del self.buffer[0:int(self.size/5)]
            self.size = len(self.buffer)
        
        indexes = np.random.randint(0, len(self.buffer), size=batch_size)
        state, action, reward, next_state, done = [], [], [], [], []
        
        for i in indexes:
            s, a, r, s_, d = self.buffer[i]
            state.append(np.array(s, copy=False))
            action.append(np.array(a, copy=False))
            reward.append(np.array(r, copy=False))
            next_state.append(np.array(s_, copy=False))
            done.append(np.array(d, copy=False))
        
        return np.array(state), np.array(action), np.array(reward), np.array(next_state), np.array(done)

# %%
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()
        
        self.l1 = nn.Linear(state_dim, 400)
        self.l2 = nn.Linear(400, 300)
        self.l3 = nn.Linear(300, action_dim)
        
        self.max_action = max_action
        
    def forward(self, state):
        a = F.relu(self.l1(state))
        a = F.relu(self.l2(a))
        a = torch.tanh(self.l3(a)) * self.max_action
        return a
        
class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()
        
        self.l1 = nn.Linear(state_dim + action_dim, 400)
        self.l2 = nn.Linear(400, 300)
        self.l3 = nn.Linear(300, 1)
        
    def forward(self, state, action):
        state_action = torch.cat([state, action], 1)
        
        q = F.relu(self.l1(state_action))
        q = F.relu(self.l2(q))
        q = self.l3(q)
        return q
    
class TD3:
    def __init__(self, lr, state_dim, action_dim, max_action):
        
        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target.load_state_dict(self.actor.state_dict())
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=lr)
        
        self.critic_1 = Critic(state_dim, action_dim).to(device)
        self.critic_1_target = Critic(state_dim, action_dim).to(device)
        self.critic_1_target.load_state_dict(self.critic_1.state_dict())
        self.critic_1_optimizer = optim.Adam(self.critic_1.parameters(), lr=lr)
        
        self.critic_2 = Critic(state_dim, action_dim).to(device)
        self.critic_2_target = Critic(state_dim, action_dim).to(device)
        self.critic_2_target.load_state_dict(self.critic_2.state_dict())
        self.critic_2_optimizer = optim.Adam(self.critic_2.parameters(), lr=lr)
        
        self.max_action = max_action
    
    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()
    
    def update(self, replay_buffer, n_iter, batch_size, gamma, polyak, policy_noise, noise_clip, policy_delay):
        
        for i in range(n_iter):
            # Sample a batch of transitions from replay buffer:
            state, action_, reward, next_state, done = replay_buffer.sample(batch_size)
            state = torch.FloatTensor(state).to(device)
            action = torch.FloatTensor(action_).to(device)
            reward = torch.FloatTensor(reward).reshape((batch_size,1)).to(device)
            next_state = torch.FloatTensor(next_state).to(device)
            done = torch.FloatTensor(done).reshape((batch_size,1)).to(device)
            
            # Select next action according to target policy:
            noise = torch.FloatTensor(action_).data.normal_(0, policy_noise).to(device)
            noise = noise.clamp(-noise_clip, noise_clip)
            next_action = (self.actor_target(next_state) + noise)
            next_action = next_action.clamp(-self.max_action, self.max_action)
            
            # Compute target Q-value:
            target_Q1 = self.critic_1_target(next_state, next_action)
            target_Q2 = self.critic_2_target(next_state, next_action)
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + ((1-done) * gamma * target_Q).detach()
            
            # Optimize Critic 1:
            current_Q1 = self.critic_1(state, action)
            loss_Q1 = F.mse_loss(current_Q1, target_Q)
            self.critic_1_optimizer.zero_grad()
            loss_Q1.backward()
            self.critic_1_optimizer.step()
            
            # Optimize Critic 2:
            current_Q2 = self.critic_2(state, action)
            loss_Q2 = F.mse_loss(current_Q2, target_Q)
            self.critic_2_optimizer.zero_grad()
            loss_Q2.backward()
            self.critic_2_optimizer.step()
            
            # Delayed policy updates:
            if i % policy_delay == 0:
                # Compute actor loss:
                actor_loss = -self.critic_1(state, self.actor(state)).mean()
                
                # Optimize the actor
                self.actor_optimizer.zero_grad()
                actor_loss.backward()
                self.actor_optimizer.step()
                
                # Polyak averaging update:
                for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                    target_param.data.copy_( (polyak * target_param.data) + ((1-polyak) * param.data))
                
                for param, target_param in zip(self.critic_1.parameters(), self.critic_1_target.parameters()):
                    target_param.data.copy_( (polyak * target_param.data) + ((1-polyak) * param.data))
                
                for param, target_param in zip(self.critic_2.parameters(), self.critic_2_target.parameters()):
                    target_param.data.copy_( (polyak * target_param.data) + ((1-polyak) * param.data))
                    
                
    def save(self, directory, name):
        torch.save(self.actor.state_dict(), '%s/%s_actor.pth' % (directory, name))
        torch.save(self.actor_target.state_dict(), '%s/%s_actor_target.pth' % (directory, name))
        
        torch.save(self.critic_1.state_dict(), '%s/%s_crtic_1.pth' % (directory, name))
        torch.save(self.critic_1_target.state_dict(), '%s/%s_critic_1_target.pth' % (directory, name))
        
        torch.save(self.critic_2.state_dict(), '%s/%s_crtic_2.pth' % (directory, name))
        torch.save(self.critic_2_target.state_dict(), '%s/%s_critic_2_target.pth' % (directory, name))
        
    def load(self, directory, name):
        self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, name), map_location=lambda storage, loc: storage))
        self.actor_target.load_state_dict(torch.load('%s/%s_actor_target.pth' % (directory, name), map_location=lambda storage, loc: storage))
        
        self.critic_1.load_state_dict(torch.load('%s/%s_crtic_1.pth' % (directory, name), map_location=lambda storage, loc: storage))
        self.critic_1_target.load_state_dict(torch.load('%s/%s_critic_1_target.pth' % (directory, name), map_location=lambda storage, loc: storage))
        
        self.critic_2.load_state_dict(torch.load('%s/%s_crtic_2.pth' % (directory, name), map_location=lambda storage, loc: storage))
        self.critic_2_target.load_state_dict(torch.load('%s/%s_critic_2_target.pth' % (directory, name), map_location=lambda storage, loc: storage))
        
        
    def load_actor(self, directory, name):
        self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, name), map_location=lambda storage, loc: storage))
        self.actor_target.load_state_dict(torch.load('%s/%s_actor_target.pth' % (directory, name), map_location=lambda storage, loc: storage))
# Out:
# episode: 2256
# episode length: 85
# episode reward: 27.62357543348556
# current timestep: 30399
#
# episode: 2257
# episode length: 86
# episode reward: 28.253464308683494
# current timestep: 30485
#
# episode: 2258
# episode length: 98
# episode reward: 39.36948244703435
# current timestep: 30583
#
# episode: 2259
# episode length: 89
# episode reward: 31.415976916624807
# current timestep: 30672
#
# episode: 2260
# episode length: 95
# episode reward: 37.160364489841804
# current timestep: 30767
#
# episode: 2261
# episode length: 84
# episode reward: 27.21930539056115
# current timestep: 30851
#
# episode: 2262
# episode length: 94
# episode reward: 35.907474491769044
# current timestep: 30945
#
# episode: 2263
# episode length: 81
# episode reward: 24.82054050297668
# current timestep: 31026
#
# episode: 2264
# episode length: 84
# episode reward: 26.78520929929127
# current timestep: 31110
#
# episode: 2265
# episode length: 85
# episode reward: 27.333834718536455
# current timestep: 31195
#
# episode: 2266
# episode length: 85
# episode reward: 28.004934086562447
# current timestep: 31280
#
# episode: 2267
# episode length: 90
# episode reward: 32.67792449370924
# current timestep: 31370
#
# episode: 2268
# episode length: 83
# episode reward: 26.51184759554667
# current timestep: 31453
#
# episode: 2269
# episode length: 89
# episode reward: 30.55947753493618
# current timestep: 31542
#
# episode: 2270
# episode length: 89
# episode reward: 30.94064283524096
# current timestep: 31631
#
# episode: 2271
# episode length: 86
# episode reward: 27.642502645748095
# current timestep: 31717
#
# episode: 2272
# episode length: 85
# episode reward: 27.500365497984504
# current timestep: 31802
#
# episode: 2273
# episode length: 88
# episode reward: 29.767419254000906
# current timestep: 31890
#
# episode: 2274
# episode length: 92
# episode reward: 34.92035015839357
# current timestep: 31982
#
# episode: 2275
# episode length: 90
# episode reward: 32.159691890215214
# current timestep: 32072
#
# episode: 2276
# episode length: 86
# episode reward: 29.12690702429165
# current timestep: 32158
#
# episode: 2277
# episode length: 85
# episode reward: 28.08767918288388
# current timestep: 32243
#
# episode: 2278
# episode length: 91
# episode reward: 33.783208652689886
# current timestep: 32334
#
# episode: 2279
# episode length: 85
# episode reward: 27.428642841795128
# current timestep: 32419
#
# episode: 2280
# episode length: 92
# episode reward: 34.18236202056313
# current timestep: 32511
#
# episode: 2281
# episode length: 90
# episode reward: 32.93107277069087
# current timestep: 32601
#
# episode: 2282
# episode length: 87
# episode reward: 29.592848365475792
# current timestep: 32688
#
# episode: 2283
# episode length: 71
# episode reward: 129.2868971185682
# current timestep: 32759
#
# episode: 2284
# episode length: 131
# episode reward: 189.6117650898548
# current timestep: 32890
#
# episode: 2285
# episode length: 79
# episode reward: 20.933429750996105
# current timestep: 32969
#
# episode: 2286
# episode length: 97
# episode reward: 154.25096150781445
# current timestep: 33066
#
# episode: 2287
# episode length: 66
# episode reward: 6.966156559485847
# current timestep: 33132
#
# episode: 2288
# episode length: 85
# episode reward: 25.66675610186362
# current timestep: 33217
#
# episode: 2289
# episode length: 56
# episode reward: -4.590673406863899
# current timestep: 33273
#
# episode: 2290
# episode length: 59
# episode reward: -0.047228062850547925
# current timestep: 33332
#
# episode: 2291
# episode length: 56
# episode reward: -4.059396312396845
# current timestep: 33388
#
# episode: 2292
# episode length: 52
# episode reward: -7.816297119277291
# current timestep: 33440
#
# episode: 2293
# episode length: 55
# episode reward: -2.3141589942957403
# current timestep: 33495
#
# episode: 2294
# episode length: 40
# episode reward: -17.157710294880157
# current timestep: 33535
#
# episode: 2295
# episode length: 38
# episode reward: -15.198847309484535
# current timestep: 33573
#
# episode: 2296
# episode length: 34
# episode reward: -8.215084852168502
# current timestep: 33607
#
# episode: 2297
# episode length: 34
# episode reward: -4.35915517912353
# current timestep: 33641
#
# episode: 2298
# episode length: 33
# episode reward: -3.5942504869781793
# current timestep: 33674
#
# episode: 2299
# episode length: 36
# episode reward: -7.906150990204289
# current timestep: 33710
#
# episode: 2300
# episode length: 39
# episode reward: -10.816662624710759
# current timestep: 33749
#
# avg. reward: 32.04854350601839
#
# episode: 2301
# episode length: 33
# episode reward: -15.226379432488825
# current timestep: 33782
#
# episode: 2302
# episode length: 48
# episode reward: -25.690172601783015
# current timestep: 33830
#
# episode: 2303
# episode length: 47
# episode reward: -23.84646625763356
# current timestep: 33877
#
# episode: 2304
# episode length: 49
# episode reward: -28.57163333115481
# current timestep: 33926
#
# episode: 2305
# episode length: 48
# episode reward: -26.61630813092
# current timestep: 33974
#
# episode: 2306
# episode length: 50
# episode reward: -28.180885172118913
# current timestep: 34024
#
# episode: 2307
# episode length: 51
# episode reward: -31.71298867836946
# current timestep: 34075
#
# episode: 2308
# episode length: 48
# episode reward: -24.136311745194448
# current timestep: 34123
#
# episode: 2309
# episode length: 49
# episode reward: -26.165214211600222
# current timestep: 34172
#
# episode: 2310
# episode length: 49
# episode reward: -25.507493907678402
# current timestep: 34221
#
# episode: 2311
# episode length: 49
# episode reward: -28.70021525457615
# current timestep: 34270
#
# episode: 2312
# episode length: 56
# episode reward: -43.98941279612814
# current timestep: 34326
#
# episode: 2313
# episode length: 52
# episode reward: -33.46630265252777
# current timestep: 34378
#
# episode: 2314
# episode length: 51
# episode reward: -29.857417349833938
# current timestep: 34429
#
# episode: 2315
# episode length: 53
# episode reward: -36.17307703552249
# current timestep: 34482
#
# episode: 2316
# episode length: 50
# episode reward: -28.126945972943112
# current timestep: 34532
#
# episode: 2317
# episode length: 49
# episode reward: -25.67876358806871
# current timestep: 34581
#
# episode: 2318
# episode length: 50
# episode reward: -30.14523050900084
# current timestep: 34631
#
# episode: 2319
# episode length: 55
# episode reward: -42.6472280202308
# current timestep: 34686
#
# episode: 2320
# episode length: 53
# episode reward: -36.11280662558617
# current timestep: 34739
#
# episode: 2321
# episode length: 52
# episode reward: -30.88455503476871
# current timestep: 34791
#
# episode: 2322
# episode length: 53
# episode reward: -33.2156828087701
# current timestep: 34844
#
# episode: 2323
# episode length: 47
# episode reward: -21.2584407306666
# current timestep: 34891
#
# episode: 2324
# episode length: 53
# episode reward: -36.12583997240648
# current timestep: 34944
#
# episode: 2325
# episode length: 53
# episode reward: -34.54808414367253
# current timestep: 34997
#
# episode: 2326
# episode length: 49
# episode reward: -25.602460150517775
# current timestep: 35046
#
# episode: 2327
# episode length: 52
# episode reward: -32.788021424588905
# current timestep: 35098
#
# episode: 2328
# episode length: 51
# episode reward: -32.17544474876995
# current timestep: 35149
#
# episode: 2329
# episode length: 53
# episode reward: -34.53508330073472
# current timestep: 35202
#
# episode: 2330
# episode length: 51
# episode reward: -29.856235812018266
# current timestep: 35253
#
# episode: 2331
# episode length: 52
# episode reward: -34.31777340948483
# current timestep: 35305
#
# episode: 2332
# episode length: 55
# episode reward: -43.971490740362725
# current timestep: 35360
#
# episode: 2333
# episode length: 51
# episode reward: -32.49491592142252
# current timestep: 35411
#
# episode: 2334
# episode length: 53
# episode reward: -34.290475134279895
# current timestep: 35464
#
# episode: 2335
# episode length: 52
# episode reward: -29.815681363519428
# current timestep: 35516
#
# episode: 2336
# episode length: 52
# episode reward: -34.44830846373516
# current timestep: 35568
#
# episode: 2337
# episode length: 50
# episode reward: -27.79681483526685
# current timestep: 35618
#
# episode: 2338
# episode length: 53
# episode reward: -33.94744133479424
# current timestep: 35671
#
# episode: 2339
# episode length: 50
# episode reward: -28.595675970557675
# current timestep: 35721
#
# episode: 2340
# episode length: 52
# episode reward: -34.82670055429794
# current timestep: 35773
#
# episode: 2341
# episode length: 51
# episode reward: -31.08181683976528
# current timestep: 35824
#
# episode: 2342
# episode length: 51
# episode reward: -31.61879755961025
# current timestep: 35875
#
# episode: 2343
# episode length: 52
# episode reward: -35.41006605433932
# current timestep: 35927
# episode: 2344
# episode length: 52
# episode reward: -32.22569746458371
# current timestep: 35979
#
# episode: 2345
# episode length: 52
# episode reward: -33.08132891006094
# current timestep: 36031
#
# episode: 2346
# episode length: 52
# episode reward: -31.739953598425434
# current timestep: 36083
#
# episode: 2347
# episode length: 51
# episode reward: -29.888409257032
# current timestep: 36134
#
# episode: 2348
# episode length: 53
# episode reward: -39.533894372969606
# current timestep: 36187
#
# episode: 2349
# episode length: 52
# episode reward: -34.13455691440129
# current timestep: 36239
#
# episode: 2350
# episode length: 49
# episode reward: -27.358318452447637
# current timestep: 36288
#
# episode: 2351
# episode length: 53
# episode reward: -34.9330278587643
# current timestep: 36341
#
# episode: 2352
# episode length: 52
# episode reward: -33.0599857960234
# current timestep: 36393
#
# episode: 2353
# episode length: 53
# episode reward: -34.81001439014153
# current timestep: 36446
#
# episode: 2354
# episode length: 51
# episode reward: -30.21366771750571
# current timestep: 36497
#
# episode: 2355
# episode length: 52
# episode reward: -33.825025538322095
# current timestep: 36549
#
# episode: 2356
# episode length: 49
# episode reward: -26.335260429201234
# current timestep: 36598
#
# episode: 2357
# episode length: 54
# episode reward: -37.633312678320564
# current timestep: 36652
#
# episode: 2358
# episode length: 53
# episode reward: -35.41556129842071
# current timestep: 36705
#
# episode: 2359
# episode length: 53
# episode reward: -36.40495816113741
# current timestep: 36758
#
# episode: 2360
# episode length: 53
# episode reward: -32.48354547709002
# current timestep: 36811
#
# episode: 2361
# episode length: 54
# episode reward: -41.78329862926656
# current timestep: 36865
#
# episode: 2362
# episode length: 49
# episode reward: -26.952062595276182
# current timestep: 36914
#
# episode: 2363
# episode length: 53
# episode reward: -34.245698928089354
# current timestep: 36967
#
# episode: 2364
# episode length: 53
# episode reward: -39.352284515971895
# current timestep: 37020
#
# episode: 2365
# episode length: 54
# episode reward: -34.96664649604213
# current timestep: 37074
#
# episode: 2366
# episode length: 54
# episode reward: -38.14953306407993
# current timestep: 37128
#
# episode: 2367
# episode length: 52
# episode reward: -33.42478306149913
# current timestep: 37180
#
# episode: 2368
# episode length: 54
# episode reward: -36.821935534940984
# current timestep: 37234
#
# episode: 2369
# episode length: 49
# episode reward: -26.761723376941116
# current timestep: 37283
#
# episode: 2370
# episode length: 50
# episode reward: -28.46823812951545
# current timestep: 37333
#
# episode: 2371
# episode length: 53
# episode reward: -37.534461629819546
# current timestep: 37386
#
# episode: 2372
# episode length: 50
# episode reward: -27.099382271208004
# current timestep: 37436
#
# episode: 2373
# episode length: 52
# episode reward: -32.15918692459516
# current timestep: 37488
#
# episode: 2374
# episode length: 53
# episode reward: -36.02316572698623
# current timestep: 37541
#
# episode: 2375
# episode length: 51
# episode reward: -26.598067255601844
# current timestep: 37592
#
# episode: 2376
# episode length: 37
# episode reward: -6.829255752844522
# current timestep: 37629
#
# episode: 2377
# episode length: 30
# episode reward: -5.474396959322204
# current timestep: 37659
#
# episode: 2378
# episode length: 29
# episode reward: -4.193252902070768
# current timestep: 37688
#
# episode: 2379
# episode length: 36
# episode reward: -2.2955848306075013
# current timestep: 37724
#
# episode: 2380
# episode length: 38
# episode reward: -8.373453595862804
# current timestep: 37762
#
# episode: 2381
# episode length: 31
# episode reward: -4.848449831701049
# current timestep: 37793
#
# episode: 2382
# episode length: 32
# episode reward: -3.217924507272256
# current timestep: 37825
#
# episode: 2383
# episode length: 36
# episode reward: -7.205098253269066
# current timestep: 37861
#
# episode: 2384
# episode length: 36
# episode reward: -6.500476086588064
# current timestep: 37897
#
# episode: 2385
# episode length: 37
# episode reward: -5.1535891926997754
# current timestep: 37934
#
# episode: 2386
# episode length: 37
# episode reward: -5.685702605897043
# current timestep: 37971
#
# episode: 2387
# episode length: 32
# episode reward: -4.923683791349739
# current timestep: 38003
#
# episode: 2388
# episode length: 41
# episode reward: -7.621945693547312
# current timestep: 38044
#
# episode: 2389
# episode length: 36
# episode reward: -4.21823842686547
# current timestep: 38080
#
# episode: 2390
# episode length: 31
# episode reward: -3.3976627463055595
# current timestep: 38111
#
# episode: 2391
# episode length: 30
# episode reward: -3.189221423855866
# current timestep: 38141
#
# episode: 2392
# episode length: 31
# episode reward: -4.0462599904973064
# current timestep: 38172
#
# episode: 2393
# episode length: 29
# episode reward: -3.9783110188938973
# current timestep: 38201
#
# episode: 2394
# episode length: 32
# episode reward: -3.2983743168161084
# current timestep: 38233
#
# episode: 2395
# episode length: 40
# episode reward: -8.161862878980918
# current timestep: 38273
#
# episode: 2396
# episode length: 44
# episode reward: -7.135358121793076
# current timestep: 38317
#
# episode: 2397
# episode length: 36
# episode reward: -1.621376777614148
# current timestep: 38353
#
# episode: 2398
# episode length: 34
# episode reward: -3.818161870040307
# current timestep: 38387
#
# episode: 2399
# episode length: 32
# episode reward: -3.434004341739968
# current timestep: 38419
#
# episode: 2400
# episode length: 35
# episode reward: -1.0189057767487224
# current timestep: 38454
#
# avg. reward: -25.17214597729575
#
# episode: 2401
# episode length: 35
# episode reward: 0.15267530575773208
# current timestep: 38489
#
# episode: 2402
# episode length: 35
# episode reward: -1.1299226540850378
# current timestep: 38524
#
# episode: 2403
# episode length: 42
# episode reward: 1.4935076073602325
# current timestep: 38566
#
# episode: 2404
# episode length: 41
# episode reward: 2.444015800720228
# current timestep: 38607
#
# episode: 2405
# episode length: 39
# episode reward: -6.437189606416084
# current timestep: 38646
#
# episode: 2406
# episode length: 39
# episode reward: 1.0013467841601071
# current timestep: 38685
#
# episode: 2407
# episode length: 33
# episode reward: -3.5677734127883083
# current timestep: 38718
#
# episode: 2408
# episode length: 35
# episode reward: -1.3546656761080036
# current timestep: 38753
#
# episode: 2409
# episode length: 42
# episode reward: -8.86204525222907
# current timestep: 38795
#
# episode: 2410
# episode length: 31
# episode reward: -2.931419869796396
# current timestep: 38826
#
# episode: 2411
# episode length: 36
# episode reward: 0.1377512539419804
# current timestep: 38862
#
# episode: 2412
# episode length: 34
# episode reward: -2.3807017386491225
# current timestep: 38896
#
# episode: 2413
# episode length: 38
# episode reward: -1.2758863303997237
# current timestep: 38934
#
# episode: 2414
# episode length: 38
# episode reward: -4.884197029200947
# current timestep: 38972
#
# episode: 2415
# episode length: 36
# episode reward: -1.6203580223632734
# current timestep: 39008
#
# episode: 2416
# episode length: 33
# episode reward: -4.553907070746152
# current timestep: 39041
#
# episode: 2417
# episode length: 38
# episode reward: -1.6542596412533601
# current timestep: 39079
#
# episode: 2418
# episode length: 44
# episode reward: -2.3045959167538292
# current timestep: 39123
#
# episode: 2419
# episode length: 37
# episode reward: -1.8950990947756348
# current timestep: 39160
#
# episode: 2420
# episode length: 36
# episode reward: -2.954174087168872
# current timestep: 39196
#
# episode: 2421
# episode length: 36
# episode reward: -0.723026902781153
# current timestep: 39232
#
# episode: 2422
# episode length: 35
# episode reward: -4.214225746535784
# current timestep: 39267
#
# episode: 2423
# episode length: 35
# episode reward: -1.5315065617199222
# current timestep: 39302
#
# episode: 2424
# episode length: 39
# episode reward: -5.232716385025481
# current timestep: 39341
#
# episode: 2425
# episode length: 36
# episode reward: 0.5767182045570297
# current timestep: 39377
#
# episode: 2426
# episode length: 34
# episode reward: -3.1262745354797765
# current timestep: 39411
#
# episode: 2427
# episode length: 34
# episode reward: -3.307099289242333
# current timestep: 39445
#
# episode: 2428
# episode length: 33
# episode reward: -4.478470844250348
# current timestep: 39478
#
# episode: 2429
# episode length: 34
# episode reward: -3.729220571365555
# current timestep: 39512
#
# episode: 2430
# episode length: 33
# episode reward: -2.9693770467682343
# current timestep: 39545
#
# episode: 2431
# episode length: 36
# episode reward: -3.822890569996157
# current timestep: 39581
# episode: 2432
# episode length: 40
# episode reward: -4.811576550462265
# current timestep: 39621
#
# episode: 2433
# episode length: 34
# episode reward: -5.074755141324133
# current timestep: 39655
#
# episode: 2434
# episode length: 32
# episode reward: -3.1455664038305056
# current timestep: 39687
#
# episode: 2435
# episode length: 38
# episode reward: -1.2438885044655252
# current timestep: 39725
#
# episode: 2436
# episode length: 36
# episode reward: -4.810783156109407
# current timestep: 39761
#
# episode: 2437
# episode length: 34
# episode reward: -0.7087613775379771
# current timestep: 39795
#
# episode: 2438
# episode length: 34
# episode reward: -4.125682355152814
# current timestep: 39829
#
# episode: 2439
# episode length: 39
# episode reward: -0.7738957333457873
# current timestep: 39868
#
# episode: 2440
# episode length: 35
# episode reward: -2.478669308536079
# current timestep: 39903
#
# episode: 2441
# episode length: 35
# episode reward: -2.193078309594314
# current timestep: 39938
#
# episode: 2442
# episode length: 40
# episode reward: -9.235768503570773
# current timestep: 39978
#
# episode: 2443
# episode length: 42
# episode reward: -1.3535931786273658
# current timestep: 40020
#
# episode: 2444
# episode length: 42
# episode reward: -2.9930335872828806
# current timestep: 40062
#
# episode: 2445
# episode length: 51
# episode reward: 4.939068144448614
# current timestep: 40113
#
# episode: 2446
# episode length: 35
# episode reward: -2.3364503181123863
# current timestep: 40148
#
# episode: 2447
# episode length: 34
# episode reward: -3.7775157393752647
# current timestep: 40182
#
# episode: 2448
# episode length: 48
# episode reward: 5.105423104338163
# current timestep: 40230
#
# episode: 2449
# episode length: 38
# episode reward: -0.7131472970154673
# current timestep: 40268
#
# episode: 2450
# episode length: 32
# episode reward: -3.8548229968825627
# current timestep: 40300
#
# episode: 2451
# episode length: 34
# episode reward: -4.5464234455522705
# current timestep: 40334
#
# episode: 2452
# episode length: 33
# episode reward: -4.0033505484007605
# current timestep: 40367
#
# episode: 2453
# episode length: 36
# episode reward: -2.2566067725417156
# current timestep: 40403
#
# episode: 2454
# episode length: 46
# episode reward: -5.221960031488204
# current timestep: 40449
#
# episode: 2455
# episode length: 76
# episode reward: 22.991105288113133
# current timestep: 40525
#
# episode: 2456
# episode length: 33
# episode reward: -4.031843721092803
# current timestep: 40558
#
# episode: 2457
# episode length: 44
# episode reward: -1.4065976641476388
# current timestep: 40602
#
# episode: 2458
# episode length: 37
# episode reward: -3.399917908590731
# current timestep: 40639
#
# episode: 2459
# episode length: 37
# episode reward: -1.824424212167337
# current timestep: 40676
#
# episode: 2460
# episode length: 40
# episode reward: -4.323968775108837
# current timestep: 40716
#
# episode: 2461
# episode length: 37
# episode reward: -1.1178046488164437
# current timestep: 40753
#
# episode: 2462
# episode length: 37
# episode reward: -3.212471731646323
# current timestep: 40790
#
# episode: 2463
# episode length: 35
# episode reward: -2.923143751054859
# current timestep: 40825
#
# episode: 2464
# episode length: 38
# episode reward: -3.9143817827272587
# current timestep: 40863
#
# episode: 2465
# episode length: 32
# episode reward: -2.533368770274654
# current timestep: 40895
#
# episode: 2466
# episode length: 44
# episode reward: 2.9811305353022313
# current timestep: 40939
#
# episode: 2467
# episode length: 32
# episode reward: -4.432373984659224
# current timestep: 40971
#
# episode: 2468
# episode length: 37
# episode reward: -0.5626304622886649
# current timestep: 41008
#
# episode: 2469
# episode length: 34
# episode reward: -3.0198379387626
# current timestep: 41042
#
# episode: 2470
# episode length: 38
# episode reward: -2.238528002361145
# current timestep: 41080
#
# episode: 2471
# episode length: 37
# episode reward: -2.4086084226046998
# current timestep: 41117
#
# episode: 2472
# episode length: 32
# episode reward: -4.152657888335769
# current timestep: 41149
#
# episode: 2473
# episode length: 34
# episode reward: -3.428640260587218
# current timestep: 41183
#
# episode: 2474
# episode length: 37
# episode reward: -3.8137164067942693
# current timestep: 41220
#
# episode: 2475
# episode length: 34
# episode reward: -5.899803094467805
# current timestep: 41254
#
# episode: 2476
# episode length: 35
# episode reward: -3.7563243181280495
# current timestep: 41289
#
# episode: 2477
# episode length: 36
# episode reward: -4.795803798761696
# current timestep: 41325
#
# episode: 2478
# episode length: 29
# episode reward: -3.7725041407788895
# current timestep: 41354
#
# episode: 2479
# episode length: 36
# episode reward: -3.2937538313842665
# current timestep: 41390
#
# episode: 2480
# episode length: 35
# episode reward: -0.002914882251943557
# current timestep: 41425
#
# episode: 2481
# episode length: 35
# episode reward: -4.043501480036394
# current timestep: 41460
#
# episode: 2482
# episode length: 36
# episode reward: -4.880420455226266
# current timestep: 41496
#
# episode: 2483
# episode length: 28
# episode reward: -3.4683905292107777
# current timestep: 41524
#
# episode: 2484
# episode length: 28
# episode reward: -3.2262767539273285
# current timestep: 41552
#
# episode: 2485
# episode length: 30
# episode reward: -3.488114115698721
# current timestep: 41582
#
# episode: 2486
# episode length: 27
# episode reward: -4.211713471658696
# current timestep: 41609
#
# episode: 2487
# episode length: 29
# episode reward: -4.338111235888864
# current timestep: 41638
#
# episode: 2488
# episode length: 30
# episode reward: -3.1129261849601746
# current timestep: 41668
#
# episode: 2489
# episode length: 28
# episode reward: -4.094659164604487
# current timestep: 41696
#
# episode: 2490
# episode length: 28
# episode reward: -4.908388346899162
# current timestep: 41724
#
# episode: 2491
# episode length: 28
# episode reward: -3.751232844398187
# current timestep: 41752
#
# episode: 2492
# episode length: 31
# episode reward: -2.92750364029298
# current timestep: 41783
#
# episode: 2493
# episode length: 28
# episode reward: -3.223313457921432
# current timestep: 41811
#
# episode: 2494
# episode length: 29
# episode reward: -2.6003906502705405
# current timestep: 41840
#
# episode: 2495
# episode length: 29
# episode reward: -3.958696518486808
# current timestep: 41869
#
# episode: 2496
# episode length: 30
# episode reward: -2.9813516653671286
# current timestep: 41899
#
# episode: 2497
# episode length: 27
# episode reward: -2.485040818856197
# current timestep: 41926
#
# episode: 2498
# episode length: 28
# episode reward: -4.895248687291176
# current timestep: 41954
#
# episode: 2499
# episode length: 28
# episode reward: -4.338043522954726
# current timestep: 41982
#
# episode: 2500
# episode length: 27
# episode reward: -4.58345559274185
# current timestep: 42009
#
# avg. reward: -2.5856039062089264
#
# episode: 2501
# episode length: 31
# episode reward: -3.042943347286496
# current timestep: 42040
#
# episode: 2502
# episode length: 28
# episode reward: -3.3459171423654697
# current timestep: 42068
#
# episode: 2503
# episode length: 28
# episode reward: -5.711889405882129
# current timestep: 42096
#
# episode: 2504
# episode length: 29
# episode reward: -3.7261256032947783
# current timestep: 42125
#
# episode: 2505
# episode length: 29
# episode reward: -3.575227839725598
# current timestep: 42154
#
# episode: 2506
# episode length: 28
# episode reward: -4.49195706169286
# current timestep: 42182
#
# episode: 2507
# episode length: 25
# episode reward: -5.209511815772556
# current timestep: 42207
#
# episode: 2508
# episode length: 25
# episode reward: -5.48026616925272
# current timestep: 42232
#
# episode: 2509
# episode length: 30
# episode reward: -5.363433232629353
# current timestep: 42262
#
# episode: 2510
# episode length: 27
# episode reward: -5.872155167121791
# current timestep: 42289
#
# episode: 2511
# episode length: 26
# episode reward: -4.928724445287167
# current timestep: 42315
#
# episode: 2512
# episode length: 30
# episode reward: -4.565555644507996
# current timestep: 42345
#
# episode: 2513
# episode length: 27
# episode reward: -5.930657533447711
# current timestep: 42372
#
# episode: 2514
# episode length: 26
# episode reward: -5.833659903745947
# current timestep: 42398
#
# episode: 2515
# episode length: 31
# episode reward: -4.999827621389203
# current timestep: 42429
#
# episode: 2516
# episode length: 30
# episode reward: -4.896807914461908
# current timestep: 42459
#
# episode: 2517
# episode length: 30
# episode reward: -4.9396521011126735
# current timestep: 42489
#
# episode: 2518
# episode length: 28
# episode reward: -6.67607078339814
# current timestep: 42517
#
# episode: 2519
# episode length: 30
# episode reward: -3.34713774863183
# current timestep: 42547
#
# episode: 2520
# episode length: 30
# episode reward: -3.8290974212154905
# current timestep: 42577
# episode: 2521
# episode length: 30
# episode reward: -4.3668069098738105
# current timestep: 42607
#
# episode: 2522
# episode length: 29
# episode reward: -4.000957852700101
# current timestep: 42636
#
# episode: 2523
# episode length: 29
# episode reward: -5.54577382886571
# current timestep: 42665
#
# episode: 2524
# episode length: 31
# episode reward: -3.192056236724817
# current timestep: 42696
#
# episode: 2525
# episode length: 29
# episode reward: -4.558469964669623
# current timestep: 42725
#
# episode: 2526
# episode length: 31
# episode reward: -4.872890466984833
# current timestep: 42756
#
# episode: 2527
# episode length: 30
# episode reward: -3.822149375900315
# current timestep: 42786
#
# episode: 2528
# episode length: 31
# episode reward: -4.805949479812241
# current timestep: 42817
#
# episode: 2529
# episode length: 30
# episode reward: -3.617534897054562
# current timestep: 42847
#
# episode: 2530
# episode length: 31
# episode reward: -4.689415319977422
# current timestep: 42878
#
# episode: 2531
# episode length: 31
# episode reward: -3.8770426948023955
# current timestep: 42909
#
# episode: 2532
# episode length: 28
# episode reward: -4.690566834507661
# current timestep: 42937
#
# episode: 2533
# episode length: 29
# episode reward: -4.436492636526117
# current timestep: 42966
#
# episode: 2534
# episode length: 30
# episode reward: -4.657169567846597
# current timestep: 42996
#
# episode: 2535
# episode length: 30
# episode reward: -3.8449338324027984
# current timestep: 43026
#
# episode: 2536
# episode length: 30
# episode reward: -4.4689736294218765
# current timestep: 43056
#
# episode: 2537
# episode length: 30
# episode reward: -4.115403690367224
# current timestep: 43086
#
# episode: 2538
# episode length: 29
# episode reward: -4.196145864441036
# current timestep: 43115
#
# episode: 2539
# episode length: 28
# episode reward: -5.268249978199428
# current timestep: 43143
#
# episode: 2540
# episode length: 29
# episode reward: -4.0669086923963675
# current timestep: 43172
#
# episode: 2541
# episode length: 29
# episode reward: -4.852049274072981
# current timestep: 43201
#
# episode: 2542
# episode length: 30
# episode reward: -3.760282057091381
# current timestep: 43231
#
# episode: 2543
# episode length: 29
# episode reward: -5.181633591470435
# current timestep: 43260
#
# episode: 2544
# episode length: 30
# episode reward: -4.083560670234111
# current timestep: 43290
#
# episode: 2545
# episode length: 30
# episode reward: -4.6021134648778785
# current timestep: 43320
#
# episode: 2546
# episode length: 30
# episode reward: -4.610890329732073
# current timestep: 43350
#
# episode: 2547
# episode length: 29
# episode reward: -4.168225332618367
# current timestep: 43379
#
# episode: 2548
# episode length: 30
# episode reward: -4.132154677637438
# current timestep: 43409
#
# episode: 2549
# episode length: 30
# episode reward: -5.359360796875403
# current timestep: 43439
#
# episode: 2550
# episode length: 30
# episode reward: -4.6184658154553295
# current timestep: 43469
#
# episode: 2551
# episode length: 30
# episode reward: -5.428705225653197
# current timestep: 43499
#
# episode: 2552
# episode length: 30
# episode reward: -5.298112577868561
# current timestep: 43529
#
# episode: 2553
# episode length: 29
# episode reward: -5.92526904879617
# current timestep: 43558
#
# episode: 2554
# episode length: 30
# episode reward: -4.935474302140828
# current timestep: 43588
#
# episode: 2555
# episode length: 29
# episode reward: -5.157638220626323
# current timestep: 43617
#
# episode: 2556
# episode length: 29
# episode reward: -4.9336996286477905
# current timestep: 43646
#
# episode: 2557
# episode length: 30
# episode reward: -4.666085255988309
# current timestep: 43676
#
# episode: 2558
# episode length: 30
# episode reward: -5.389789249791006
# current timestep: 43706
#
# episode: 2559
# episode length: 29
# episode reward: -4.661653419996064
# current timestep: 43735
#
# episode: 2560
# episode length: 29
# episode reward: -4.719170309550908
# current timestep: 43764
#
# episode: 2561
# episode length: 29
# episode reward: -4.128942814151572
# current timestep: 43793
#
# episode: 2562
# episode length: 31
# episode reward: -4.366889142560825
# current timestep: 43824
#
# episode: 2563
# episode length: 29
# episode reward: -5.8191947836759015
# current timestep: 43853
#
# episode: 2564
# episode length: 29
# episode reward: -3.745903342383223
# current timestep: 43882
#
# episode: 2565
# episode length: 30
# episode reward: -3.8385194070481155
# current timestep: 43912
#
# episode: 2566
# episode length: 30
# episode reward: -4.069631557831258
# current timestep: 43942
#
# episode: 2567
# episode length: 29
# episode reward: -5.224417320350067
# current timestep: 43971
#
# episode: 2568
# episode length: 30
# episode reward: -3.618385493682877
# current timestep: 44001
#
# episode: 2569
# episode length: 29
# episode reward: -4.917704330197738
# current timestep: 44030
#
# episode: 2570
# episode length: 29
# episode reward: -3.7390825098256455
# current timestep: 44059
#
# episode: 2571
# episode length: 29
# episode reward: -5.785919666764678
# current timestep: 44088
#
# episode: 2572
# episode length: 32
# episode reward: -5.012523013407158
# current timestep: 44120
#
# episode: 2573
# episode length: 29
# episode reward: -4.897752853370557
# current timestep: 44149
#
# episode: 2574
# episode length: 29
# episode reward: -4.263634507897115
# current timestep: 44178
#
# episode: 2575
# episode length: 30
# episode reward: -3.208611800432751
# current timestep: 44208
#
# episode: 2576
# episode length: 28
# episode reward: -5.15787907059846
# current timestep: 44236
#
# episode: 2577
# episode length: 29
# episode reward: -4.913966967195336
# current timestep: 44265
#
# episode: 2578
# episode length: 28
# episode reward: -6.086692322881341
# current timestep: 44293
#
# episode: 2579
# episode length: 30
# episode reward: -4.6725419739106435
# current timestep: 44323
#
# episode: 2580
# episode length: 28
# episode reward: -4.269432033860373
# current timestep: 44351
#
# episode: 2581
# episode length: 29
# episode reward: -4.590594633823944
# current timestep: 44380
#
# episode: 2582
# episode length: 29
# episode reward: -4.324177961763225
# current timestep: 44409
#
# episode: 2583
# episode length: 29
# episode reward: -3.7762928129544204
# current timestep: 44438
#
# episode: 2584
# episode length: 29
# episode reward: -3.9253954977330086
# current timestep: 44467
#
# episode: 2585
# episode length: 30
# episode reward: -3.691285264043045
# current timestep: 44497
#
# episode: 2586
# episode length: 30
# episode reward: -4.794716863419572
# current timestep: 44527
#
# episode: 2587
# episode length: 31
# episode reward: -3.5141615557247032
# current timestep: 44558
#
# episode: 2588
# episode length: 28
# episode reward: -5.411042206675062
# current timestep: 44586
#
# episode: 2589
# episode length: 29
# episode reward: -4.561014099997729
# current timestep: 44615
#
# episode: 2590
# episode length: 29
# episode reward: -4.566193416081884
# current timestep: 44644
#
# episode: 2591
# episode length: 29
# episode reward: -5.050308994255153
# current timestep: 44673
#
# episode: 2592
# episode length: 26
# episode reward: -6.215131775566207
# current timestep: 44699
#
# episode: 2593
# episode length: 29
# episode reward: -4.032215267491218
# current timestep: 44728
#
# episode: 2594
# episode length: 29
# episode reward: -5.034261177902763
# current timestep: 44757
#
# episode: 2595
# episode length: 29
# episode reward: -4.819231348946401
# current timestep: 44786
#
# episode: 2596
# episode length: 30
# episode reward: -4.34443012739533
# current timestep: 44816
#
# episode: 2597
# episode length: 29
# episode reward: -5.135490793205256
# current timestep: 44845
#
# episode: 2598
# episode length: 29
# episode reward: -4.567560739254002
# current timestep: 44874
#
# episode: 2599
# episode length: 28
# episode reward: -5.463528878647416
# current timestep: 44902
#
# episode: 2600
# episode length: 29
# episode reward: -4.986219837792508
# current timestep: 44931
#
# avg. reward: -4.638857210695198
#
# episode: 2601
# episode length: 29
# episode reward: -4.457070568936517
# current timestep: 44960
#
# episode: 2602
# episode length: 29
# episode reward: -5.975977804274596
# current timestep: 44989
#
# episode: 2603
# episode length: 31
# episode reward: -3.9169037047490973
# current timestep: 45020
#
# episode: 2604
# episode length: 29
# episode reward: -3.0450725891247528
# current timestep: 45049
#
# episode: 2605
# episode length: 29
# episode reward: -3.3055901731028774
# current timestep: 45078
#
# episode: 2606
# episode length: 29
# episode reward: -4.19781893136742
# current timestep: 45107
#
# episode: 2607
# episode length: 29
# episode reward: -4.269853765885756
# current timestep: 45136
#
# episode: 2608
# episode length: 27
# episode reward: -6.05534687250654
# current timestep: 45163
# episode: 2609
# episode length: 29
# episode reward: -4.385732441274925
# current timestep: 45192
#
# episode: 2610
# episode length: 28
# episode reward: -5.057448160932712
# current timestep: 45220
#
# episode: 2611
# episode length: 30
# episode reward: -4.998414241078807
# current timestep: 45250
#
# episode: 2612
# episode length: 29
# episode reward: -5.679814149253946
# current timestep: 45279
#
# episode: 2613
# episode length: 28
# episode reward: -5.27663668584759
# current timestep: 45307
#
# episode: 2614
# episode length: 27
# episode reward: -4.712179378339327
# current timestep: 45334
#
# episode: 2615
# episode length: 30
# episode reward: -4.77369645407697
# current timestep: 45364
#
# episode: 2616
# episode length: 30
# episode reward: -4.010817007473582
# current timestep: 45394
#
# episode: 2617
# episode length: 28
# episode reward: -5.067401877192664
# current timestep: 45422
#
# episode: 2618
# episode length: 29
# episode reward: -5.697915187768609
# current timestep: 45451
#
# episode: 2619
# episode length: 28
# episode reward: -5.489834077580864
# current timestep: 45479
#
# episode: 2620
# episode length: 28
# episode reward: -7.218268181494799
# current timestep: 45507
#
# episode: 2621
# episode length: 27
# episode reward: -6.369895695750621
# current timestep: 45534
#
# episode: 2622
# episode length: 29
# episode reward: -4.710455342596119
# current timestep: 45563
#
# episode: 2623
# episode length: 28
# episode reward: -5.452279395769577
# current timestep: 45591
#
# episode: 2624
# episode length: 30
# episode reward: -5.265723520723948
# current timestep: 45621
#
# episode: 2625
# episode length: 28
# episode reward: -6.233725567205007
# current timestep: 45649
#
# episode: 2626
# episode length: 29
# episode reward: -5.490009527307946
# current timestep: 45678
#
# episode: 2627
# episode length: 30
# episode reward: -3.7000756583963583
# current timestep: 45708
#
# episode: 2628
# episode length: 30
# episode reward: -4.777462010066857
# current timestep: 45738
#
# episode: 2629
# episode length: 29
# episode reward: -5.037346034240396
# current timestep: 45767
#
# episode: 2630
# episode length: 29
# episode reward: -3.9193001977710726
# current timestep: 45796
#
# episode: 2631
# episode length: 29
# episode reward: -4.776093939910834
# current timestep: 45825
#
# episode: 2632
# episode length: 27
# episode reward: -5.959156071319019
# current timestep: 45852
#
# episode: 2633
# episode length: 26
# episode reward: -5.490285236082945
# current timestep: 45878
#
# episode: 2634
# episode length: 29
# episode reward: -3.566941551177999
# current timestep: 45907
#
# episode: 2635
# episode length: 28
# episode reward: -5.3549319074688535
# current timestep: 45935
#
# episode: 2636
# episode length: 27
# episode reward: -4.502691693809857
# current timestep: 45962
#
# episode: 2637
# episode length: 28
# episode reward: -6.305019818432335
# current timestep: 45990
#
# episode: 2638
# episode length: 29
# episode reward: -3.861559909474094
# current timestep: 46019
#
# episode: 2639
# episode length: 28
# episode reward: -5.871893513865203
# current timestep: 46047
#
# episode: 2640
# episode length: 26
# episode reward: -5.664693650018307
# current timestep: 46073
#
# episode: 2641
# episode length: 27
# episode reward: -6.82179624623437
# current timestep: 46100
#
# episode: 2642
# episode length: 29
# episode reward: -5.813774491683345
# current timestep: 46129
#
# episode: 2643
# episode length: 29
# episode reward: -5.856994383023552
# current timestep: 46158
#
# episode: 2644
# episode length: 27
# episode reward: -4.294055299156611
# current timestep: 46185
#
# episode: 2645
# episode length: 29
# episode reward: -5.082913588938559
# current timestep: 46214
#
# episode: 2646
# episode length: 29
# episode reward: -4.97245949982773
# current timestep: 46243
#
# episode: 2647
# episode length: 28
# episode reward: -4.312315804255159
# current timestep: 46271
#
# episode: 2648
# episode length: 26
# episode reward: -6.29859669287663
# current timestep: 46297
#
# episode: 2649
# episode length: 29
# episode reward: -3.882156259874903
# current timestep: 46326
#
# episode: 2650
# episode length: 28
# episode reward: -4.878593889577527
# current timestep: 46354
#
# episode: 2651
# episode length: 27
# episode reward: -5.187163671720174
# current timestep: 46381
#
# episode: 2652
# episode length: 29
# episode reward: -4.770432302124972
# current timestep: 46410
#
# episode: 2653
# episode length: 26
# episode reward: -4.953438519112032
# current timestep: 46436
#
# episode: 2654
# episode length: 27
# episode reward: -5.325734242099981
# current timestep: 46463
#
# episode: 2655
# episode length: 25
# episode reward: -4.943658355136977
# current timestep: 46488
#
# episode: 2656
# episode length: 30
# episode reward: -3.770878551861939
# current timestep: 46518
#
# episode: 2657
# episode length: 28
# episode reward: -4.516734952009862
# current timestep: 46546
#
# episode: 2658
# episode length: 28
# episode reward: -5.38242301132356
# current timestep: 46574
#
# episode: 2659
# episode length: 30
# episode reward: -5.040480473149824
# current timestep: 46604
#
# episode: 2660
# episode length: 28
# episode reward: -4.940052539161241
# current timestep: 46632
#
# episode: 2661
# episode length: 26
# episode reward: -5.784410289395851
# current timestep: 46658
#
# episode: 2662
# episode length: 24
# episode reward: -6.208373182404554
# current timestep: 46682
#
# episode: 2663
# episode length: 29
# episode reward: -4.488600851348887
# current timestep: 46711
#
# episode: 2664
# episode length: 27
# episode reward: -4.216615130598678
# current timestep: 46738
#
# episode: 2665
# episode length: 25
# episode reward: -1.6512319862300977
# current timestep: 46763
#
# episode: 2666
# episode length: 27
# episode reward: -2.9279863025122106
# current timestep: 46790
#
# episode: 2667
# episode length: 25
# episode reward: -3.1445409562858955
# current timestep: 46815
#
# episode: 2668
# episode length: 29
# episode reward: -4.065656026736892
# current timestep: 46844
#
# episode: 2669
# episode length: 29
# episode reward: -4.260851573864611
# current timestep: 46873
#
# episode: 2670
# episode length: 29
# episode reward: -4.46445906721066
# current timestep: 46902
#
# episode: 2671
# episode length: 28
# episode reward: -3.4658225804299767
# current timestep: 46930
#
# episode: 2672
# episode length: 25
# episode reward: -6.3675186252520195
# current timestep: 46955
#
# episode: 2673
# episode length: 26
# episode reward: -4.971268365935524
# current timestep: 46981
#
# episode: 2674
# episode length: 28
# episode reward: -2.7072735480239034
# current timestep: 47009
#
# episode: 2675
# episode length: 28
# episode reward: -5.631015099239187
# current timestep: 47037
#
# episode: 2676
# episode length: 30
# episode reward: -4.32886661212367
# current timestep: 47067
#
# episode: 2677
# episode length: 28
# episode reward: -4.925154559564821
# current timestep: 47095
#
# episode: 2678
# episode length: 24
# episode reward: -4.173756675152062
# current timestep: 47119
#
# episode: 2679
# episode length: 26
# episode reward: -4.205444053302925
# current timestep: 47145
#
# episode: 2680
# episode length: 30
# episode reward: -2.9538573271779978
# current timestep: 47175
#
# episode: 2681
# episode length: 27
# episode reward: -3.6858209659786723
# current timestep: 47202
#
# episode: 2682
# episode length: 29
# episode reward: -4.258378587234382
# current timestep: 47231
#
# episode: 2683
# episode length: 25
# episode reward: -6.7761780434037115
# current timestep: 47256
#
# episode: 2684
# episode length: 28
# episode reward: -4.467175626802463
# current timestep: 47284
#
# episode: 2685
# episode length: 26
# episode reward: -6.09451652382211
# current timestep: 47310
#
# episode: 2686
# episode length: 30
# episode reward: -4.028964261913785
# current timestep: 47340
#
# episode: 2687
# episode length: 26
# episode reward: -2.166145575985977
# current timestep: 47366
#
# episode: 2688
# episode length: 24
# episode reward: -6.620927391560486
# current timestep: 47390
#
# episode: 2689
# episode length: 24
# episode reward: -4.191862721838418
# current timestep: 47414
#
# episode: 2690
# episode length: 24
# episode reward: -5.822907838192459
# current timestep: 47438
#
# episode: 2691
# episode length: 26
# episode reward: -5.387174136873727
# current timestep: 47464
#
# episode: 2692
# episode length: 25
# episode reward: -4.86302753478465
# current timestep: 47489
#
# episode: 2693
# episode length: 28
# episode reward: -4.598093530259365
# current timestep: 47517
#
# episode: 2694
# episode length: 24
# episode reward: -3.55410732619387
# current timestep: 47541
#
# episode: 2695
# episode length: 23
# episode reward: -3.0557852563575243
# current timestep: 47564
#
# episode: 2696
# episode length: 25
# episode reward: -1.5241222971179296
# current timestep: 47589
#
# episode: 2697
# episode length: 26
# episode reward: -5.189537868867893
# current timestep: 47615
#
# episode: 2698
# episode length: 26
# episode reward: -1.9859838068593985
# current timestep: 47641
# episode: 2699
# episode length: 25
# episode reward: -5.75843567207172
# current timestep: 47666
#
# episode: 2700
# episode length: 29
# episode reward: -4.065836973744619
# current timestep: 47695
#
# avg. reward: -4.739836700194522
#
# episode: 2701
# episode length: 23
# episode reward: -3.8535944821006596
# current timestep: 47718
#
# episode: 2702
# episode length: 28
# episode reward: -3.981101628146825
# current timestep: 47746
#
# episode: 2703
# episode length: 23
# episode reward: -4.6175681671811555
# current timestep: 47769
#
# episode: 2704
# episode length: 27
# episode reward: -6.191800920358948
# current timestep: 47796
#
# episode: 2705
# episode length: 25
# episode reward: -1.9350974575044395
# current timestep: 47821
#
# episode: 2706
# episode length: 24
# episode reward: -5.505759657125475
# current timestep: 47845
#
# episode: 2707
# episode length: 25
# episode reward: -0.9711086206260133
# current timestep: 47870
#
# episode: 2708
# episode length: 26
# episode reward: -6.009392880158588
# current timestep: 47896
#
# episode: 2709
# episode length: 23
# episode reward: -6.329566855251014
# current timestep: 47919
#
# episode: 2710
# episode length: 27
# episode reward: -5.727373014645342
# current timestep: 47946
#
# episode: 2711
# episode length: 26
# episode reward: -6.038705545274874
# current timestep: 47972
#
# episode: 2712
# episode length: 25
# episode reward: -4.838115468803201
# current timestep: 47997
#
# episode: 2713
# episode length: 23
# episode reward: -5.039645156852471
# current timestep: 48020
#
# episode: 2714
# episode length: 25
# episode reward: -5.555102716077812
# current timestep: 48045
#
# episode: 2715
# episode length: 24
# episode reward: -6.428739078351424
# current timestep: 48069
#
# episode: 2716
# episode length: 23
# episode reward: -5.834033227537482
# current timestep: 48092
#
# episode: 2717
# episode length: 23
# episode reward: -5.362696595342455
# current timestep: 48115
#
# episode: 2718
# episode length: 23
# episode reward: -6.644642324904484
# current timestep: 48138
#
# episode: 2719
# episode length: 23
# episode reward: -5.330419578509536
# current timestep: 48161
#
# episode: 2720
# episode length: 25
# episode reward: -4.764431336154902
# current timestep: 48186
#
# episode: 2721
# episode length: 29
# episode reward: -3.8490352536664685
# current timestep: 48215
#
# episode: 2722
# episode length: 26
# episode reward: -2.5793766914753022
# current timestep: 48241
#
# episode: 2723
# episode length: 23
# episode reward: -5.616850260781935
# current timestep: 48264
#
# episode: 2724
# episode length: 25
# episode reward: -5.429580541560506
# current timestep: 48289
#
# episode: 2725
# episode length: 25
# episode reward: -5.164803530002175
# current timestep: 48314
#
# episode: 2726
# episode length: 23
# episode reward: -5.145781261990768
# current timestep: 48337
#
# episode: 2727
# episode length: 26
# episode reward: -6.523680812496997
# current timestep: 48363
#
# episode: 2728
# episode length: 24
# episode reward: -5.983006893525974
# current timestep: 48387
#
# episode: 2729
# episode length: 25
# episode reward: -0.9042012194490612
# current timestep: 48412
#
# episode: 2730
# episode length: 25
# episode reward: -5.265342544408939
# current timestep: 48437
#
# episode: 2731
# episode length: 26
# episode reward: -3.1643463334737185
# current timestep: 48463
#
# episode: 2732
# episode length: 30
# episode reward: -1.9653503952829448
# current timestep: 48493
#
# episode: 2733
# episode length: 24
# episode reward: -5.418721380886159
# current timestep: 48517
#
# episode: 2734
# episode length: 23
# episode reward: -3.473696277086127
# current timestep: 48540
#
# episode: 2735
# episode length: 25
# episode reward: -5.1446524245401015
# current timestep: 48565
#
# episode: 2736
# episode length: 23
# episode reward: -6.881125021488776
# current timestep: 48588
#
# episode: 2737
# episode length: 24
# episode reward: -2.0724748363553296
# current timestep: 48612
#
# episode: 2738
# episode length: 25
# episode reward: -3.900940969755068
# current timestep: 48637
#
# episode: 2739
# episode length: 24
# episode reward: -5.57917406062482
# current timestep: 48661
#
# episode: 2740
# episode length: 23
# episode reward: -5.386028584024981
# current timestep: 48684
#
# episode: 2741
# episode length: 26
# episode reward: -5.148553992877023
# current timestep: 48710
#
# episode: 2742
# episode length: 24
# episode reward: -2.3557418916713053
# current timestep: 48734
#
# episode: 2743
# episode length: 25
# episode reward: -6.011933675866134
# current timestep: 48759
#
# episode: 2744
# episode length: 25
# episode reward: -4.928696182792545
# current timestep: 48784
#
# episode: 2745
# episode length: 24
# episode reward: -6.275103229430783
# current timestep: 48808
#
# episode: 2746
# episode length: 29
# episode reward: -2.298258353837423
# current timestep: 48837
#
# episode: 2747
# episode length: 24
# episode reward: -5.438340674534513
# current timestep: 48861
#
# episode: 2748
# episode length: 26
# episode reward: -4.156287216531948
# current timestep: 48887
#
# episode: 2749
# episode length: 24
# episode reward: -5.679741205557913
# current timestep: 48911
#
# episode: 2750
# episode length: 25
# episode reward: -5.501572350646996
# current timestep: 48936
#
# episode: 2751
# episode length: 26
# episode reward: -4.848266964708881
# current timestep: 48962
#
# episode: 2752
# episode length: 27
# episode reward: -4.456954567362502
# current timestep: 48989
#
# episode: 2753
# episode length: 29
# episode reward: -5.167107532958146
# current timestep: 49018
#
# episode: 2754
# episode length: 26
# episode reward: -5.120150839653936
# current timestep: 49044
#
# episode: 2755
# episode length: 28
# episode reward: -4.051898862137238
# current timestep: 49072
#
# episode: 2756
# episode length: 25
# episode reward: -4.06371212463926
# current timestep: 49097
#
# episode: 2757
# episode length: 36
# episode reward: -1.745614376281177
# current timestep: 49133
#
# episode: 2758
# episode length: 25
# episode reward: -4.821453951704914
# current timestep: 49158
#
# episode: 2759
# episode length: 26
# episode reward: -4.336674798719006
# current timestep: 49184
#
# episode: 2760
# episode length: 25
# episode reward: -5.161294965469385
# current timestep: 49209
#
# episode: 2761
# episode length: 26
# episode reward: -3.1431798223090435
# current timestep: 49235
#
# episode: 2762
# episode length: 25
# episode reward: -5.347328253630927
# current timestep: 49260
#
# episode: 2763
# episode length: 32
# episode reward: -4.787613466252188
# current timestep: 49292
#
# episode: 2764
# episode length: 28
# episode reward: -3.1491993006871786
# current timestep: 49320
#
# episode: 2765
# episode length: 27
# episode reward: -4.587705294606574
# current timestep: 49347
#
# episode: 2766
# episode length: 28
# episode reward: -4.0276672676795595
# current timestep: 49375
#
# episode: 2767
# episode length: 33
# episode reward: -4.934287609285184
# current timestep: 49408
#
# episode: 2768
# episode length: 32
# episode reward: -3.7251869716263157
# current timestep: 49440
#
# episode: 2769
# episode length: 26
# ...
# current timestep: 404950
#
# episode: 10498
# episode length: 47
# episode reward: -17.065490365009897
# current timestep: 404997
#
# episode: 10499
# episode length: 47
# episode reward: -15.460164673383868
# current timestep: 405044
#
# episode: 10500
# episode length: 40
# episode reward: -8.405411745269177
# current timestep: 405084
#
# avg. reward: -14.27640026435615
#
# episode: 10501
# episode length: 44
# episode reward: -10.455787678002956
# current timestep: 405128
#
# episode: 10502
# episode length: 43
# episode reward: -9.801466447347595
# current timestep: 405171
#
# episode: 10503
# episode length: 44
# episode reward: -12.213969364485683
# current timestep: 405215
#
# episode: 10504
# episode length: 41
# episode reward: -7.914830556262999
# current timestep: 405256
#
# episode: 10505
# episode length: 44
# episode reward: -9.528980158411105
# current timestep: 405300
#
# episode: 10506
# episode length: 40
# episode reward: -7.07207639113412
# current timestep: 405340
#
# episode: 10507
# episode length: 40
# episode reward: -8.407383256944936
# current timestep: 405380
#
# episode: 10508
# episode length: 41
# episode reward: -6.973376350598229
# current timestep: 405421
#
# episode: 10509
# episode length: 49
# episode reward: -18.01967796567091
# current timestep: 405470
#
# episode: 10510
# episode length: 43
# episode reward: -9.225328403721337
# current timestep: 405513
#
# episode: 10511
# episode length: 46
# episode reward: -11.460027164064783
# current timestep: 405559
#
# episode: 10512
# episode length: 45
# episode reward: -12.408093946829478
# current timestep: 405604
#
# episode: 10513
# episode length: 46
# episode reward: -13.954905299957412
# current timestep: 405650
#
# episode: 10514
# episode length: 42
# episode reward: -7.992733522460394
# current timestep: 405692
#
# episode: 10515
# episode length: 42
# episode reward: -7.451358125427813
# current timestep: 405734
#
# episode: 10516
# episode length: 49
# episode reward: -18.60557052509302
# current timestep: 405783
#
# episode: 10517
# episode length: 48
# episode reward: -16.57210684287728
# current timestep: 405831
#
# episode: 10518
# episode length: 46
# episode reward: -13.897933064142522
# current timestep: 405877
#
# episode: 10519
# episode length: 47
# episode reward: -14.003823372163666
# current timestep: 405924
#
# episode: 10520
# episode length: 47
# episode reward: -13.448482204757882
# current timestep: 405971
#
# episode: 10521
# episode length: 44
# episode reward: -11.19113542763782
# current timestep: 406015
#
# episode: 10522
# episode length: 40
# episode reward: -6.779033454707307
# current timestep: 406055
#
# episode: 10523
# episode length: 48
# episode reward: -16.999274820002757
# current timestep: 406103
#
# episode: 10524
# episode length: 41
# episode reward: -6.456759710181028
# current timestep: 406144
#
# episode: 10525
# episode length: 55
# episode reward: -28.09466095724211
# current timestep: 406199
#
# episode: 10526
# episode length: 58
# episode reward: -36.71262509794999
# current timestep: 406257
#
# episode: 10527
# episode length: 53
# episode reward: -23.100564490116554
# current timestep: 406310
#
# episode: 10528
# episode length: 44
# episode reward: -8.061165202712559
# current timestep: 406354
#
# episode: 10529
# episode length: 48
# episode reward: -17.58908453713766
# current timestep: 406402
#
# episode: 10530
# episode length: 50
# episode reward: -20.705061530531577
# current timestep: 406452
#
# episode: 10531
# episode length: 56
# episode reward: -29.14759826968364
# current timestep: 406508
#
# episode: 10532
# episode length: 45
# episode reward: -13.738186703755495
# current timestep: 406553
#
# episode: 10533
# episode length: 44
# episode reward: -10.433544731770871
# current timestep: 406597
#
# episode: 10534
# episode length: 48
# episode reward: -14.364409155776386
# current timestep: 406645
#
# episode: 10535
# episode length: 39
# episode reward: -5.864184895464485
# current timestep: 406684
#
# episode: 10536
# episode length: 49
# episode reward: -17.397247754875544
# current timestep: 406733
#
# episode: 10537
# episode length: 48
# episode reward: -16.869328204532312
# current timestep: 406781
#
# episode: 10538
# episode length: 49
# episode reward: -17.69612285137213
# current timestep: 406830
#
# episode: 10539
# episode length: 45
# episode reward: -10.16367061733632
# current timestep: 406875
#
# episode: 10540
# episode length: 41
# episode reward: -6.944562823193492
# current timestep: 406916
#
# episode: 10541
# episode length: 47
# episode reward: -15.590264704462397
# current timestep: 406963
#
# episode: 10542
# episode length: 43
# episode reward: -7.7611608513088965
# current timestep: 407006
#
# episode: 10543
# episode length: 49
# episode reward: -17.732436272773175
# current timestep: 407055
#
# episode: 10544
# episode length: 46
# episode reward: -13.22323811712511
# current timestep: 407101
#
# episode: 10545
# episode length: 47
# episode reward: -14.682853836089162
# current timestep: 407148
#
# episode: 10546
# episode length: 43
# episode reward: -8.393596412893492
# current timestep: 407191
#
# episode: 10547
# episode length: 42
# episode reward: -8.420895000308164
# current timestep: 407233
#
# episode: 10548
# episode length: 42
# episode reward: -8.820847932684952
# current timestep: 407275
#
# episode: 10549
# episode length: 38
# episode reward: -4.427134603816338
# current timestep: 407313
#
# episode: 10550
# episode length: 51
# episode reward: -19.639566606516567
# current timestep: 407364
#
# episode: 10551
# episode length: 53
# episode reward: -19.931455187581975
# current timestep: 407417
#
# episode: 10552
# episode length: 45
# episode reward: -10.67528346784005
# current timestep: 407462
#
# episode: 10553
# episode length: 41
# episode reward: -5.703676436241517
# current timestep: 407503
#
# episode: 10554
# episode length: 48
# episode reward: -16.732892233757216
# current timestep: 407551
#
# episode: 10555
# episode length: 49
# episode reward: -15.724319304588873
# current timestep: 407600
#
# episode: 10556
# episode length: 47
# episode reward: -13.725249779464654
# current timestep: 407647
#
# episode: 10557
# episode length: 56
# episode reward: -31.66925715982015
# current timestep: 407703
#
# episode: 10558
# episode length: 50
# episode reward: -16.300084218263873
# current timestep: 407753
#
# episode: 10559
# episode length: 50
# episode reward: -17.116985093961745
# current timestep: 407803
#
# episode: 10560
# episode length: 51
# episode reward: -19.863616189563693
# current timestep: 407854
#
# episode: 10561
# episode length: 49
# episode reward: -17.338070291297576
# current timestep: 407903
# episode: 10562
# episode length: 49
# episode reward: -14.63255338085812
# current timestep: 407952
#
# episode: 10563
# episode length: 50
# episode reward: -20.597699566684057
# current timestep: 408002
#
# episode: 10564
# episode length: 49
# episode reward: -14.909543414160622
# current timestep: 408051
#
# episode: 10565
# episode length: 55
# episode reward: -29.383205291427114
# current timestep: 408106
#
# episode: 10566
# episode length: 47
# episode reward: -15.431056953095213
# current timestep: 408153
#
# episode: 10567
# episode length: 47
# episode reward: -10.856964056726406
# current timestep: 408200
#
# episode: 10568
# episode length: 50
# episode reward: -18.297186759567822
# current timestep: 408250
#
# episode: 10569
# episode length: 47
# episode reward: -12.589855450660387
# current timestep: 408297
#
# episode: 10570
# episode length: 51
# episode reward: -19.83218256841332
# current timestep: 408348
#
# episode: 10571
# episode length: 44
# episode reward: -10.919470971131831
# current timestep: 408392
#
# episode: 10572
# episode length: 49
# episode reward: -17.00710443460296
# current timestep: 408441
#
# episode: 10573
# episode length: 43
# episode reward: -9.31669986347771
# current timestep: 408484
#
# episode: 10574
# episode length: 49
# episode reward: -15.061146653239867
# current timestep: 408533
#
# episode: 10575
# episode length: 49
# episode reward: -15.60174916047765
# current timestep: 408582
#
# episode: 10576
# episode length: 47
# episode reward: -12.282363722652677
# current timestep: 408629
#
# episode: 10577
# episode length: 51
# episode reward: -21.756329292809564
# current timestep: 408680
#
# episode: 10578
# episode length: 47
# episode reward: -14.797452223802074
# current timestep: 408727
#
# episode: 10579
# episode length: 50
# episode reward: -16.643670980817454
# current timestep: 408777
#
# episode: 10580
# episode length: 48
# episode reward: -15.09966621107604
# current timestep: 408825
#
# episode: 10581
# episode length: 48
# episode reward: -15.217804055565267
# current timestep: 408873
#
# episode: 10582
# episode length: 47
# episode reward: -11.577573142470323
# current timestep: 408920
#
# episode: 10583
# episode length: 44
# episode reward: -10.17555847444884
# current timestep: 408964
#
# episode: 10584
# episode length: 50
# episode reward: -18.131591386940695
# current timestep: 409014
#
# episode: 10585
# episode length: 51
# episode reward: -19.666484005679617
# current timestep: 409065
#
# episode: 10586
# episode length: 50
# episode reward: -16.798809734566827
# current timestep: 409115
#
# episode: 10587
# episode length: 49
# episode reward: -15.508552478912533
# current timestep: 409164
#
# episode: 10588
# episode length: 48
# episode reward: -14.644620858310713
# current timestep: 409212
#
# episode: 10589
# episode length: 50
# episode reward: -19.944668757916446
# current timestep: 409262
#
# episode: 10590
# episode length: 49
# episode reward: -13.913719365127841
# current timestep: 409311
#
# episode: 10591
# episode length: 50
# episode reward: -18.824657314667526
# current timestep: 409361
#
# episode: 10592
# episode length: 49
# episode reward: -18.061155875562577
# current timestep: 409410
#
# episode: 10593
# episode length: 49
# episode reward: -16.471820367746428
# current timestep: 409459
#
# episode: 10594
# episode length: 50
# episode reward: -16.86670844166195
# current timestep: 409509
#
# episode: 10595
# episode length: 46
# episode reward: -13.776176260294047
# current timestep: 409555
#
# episode: 10596
# episode length: 50
# episode reward: -18.400180442574797
# current timestep: 409605
#
# episode: 10597
# episode length: 51
# episode reward: -18.99338182399405
# current timestep: 409656
#
# episode: 10598
# episode length: 51
# episode reward: -20.693178884778973
# current timestep: 409707
#
# episode: 10599
# episode length: 50
# episode reward: -16.993156164536103
# current timestep: 409757
#
# episode: 10600
# episode length: 50
# episode reward: -15.591041875812738
# current timestep: 409807
#
# avg. reward: -14.86455756243943
#
# episode: 10601
# episode length: 49
# episode reward: -15.557319280207826
# current timestep: 409856
#
# episode: 10602
# episode length: 51
# episode reward: -21.884706703509792
# current timestep: 409907
#
# episode: 10603
# episode length: 48
# episode reward: -16.308202402924525
# current timestep: 409955
#
# episode: 10604
# episode length: 49
# episode reward: -14.72583472761825
# current timestep: 410004
#
# episode: 10605
# episode length: 50
# episode reward: -15.281995841843374
# current timestep: 410054
#
# episode: 10606
# episode length: 51
# episode reward: -19.870631689543927
# current timestep: 410105
#
# episode: 10607
# episode length: 52
# episode reward: -17.153700162021625
# current timestep: 410157
#
# episode: 10608
# episode length: 50
# episode reward: -19.08253828333108
# current timestep: 410207
#
# episode: 10609
# episode length: 47
# episode reward: -12.81783697478168
# current timestep: 410254
#
# episode: 10610
# episode length: 47
# episode reward: -12.335132404998422
# current timestep: 410301
#
# episode: 10611
# episode length: 48
# episode reward: -14.215422862825928
# current timestep: 410349
#
# episode: 10612
# episode length: 52
# episode reward: -22.358330574452435
# current timestep: 410401
#
# episode: 10613
# episode length: 55
# episode reward: -31.151571242616722
# current timestep: 410456
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 222
#     218     return target_actor, acc_rewards
#     221 if __name__ == "__main__":
# --> 222     policy, acc_rewards = twin_delayed_deep_deterministic_policy_gradient(
#     223         gamma=0.85,
#     224         tau=0.005,
#     225         policy_noise=0.2,
#     226         noise_clip=0.5,
#     227         num_episodes=100001,
#     228         batch_size=256,
#     229         start_timestep=20000,
#     230         update_frequency=2
#     231     )
#
# Cell In[7], line 173, in twin_delayed_deep_deterministic_policy_gradient(gamma, tau, exploration_noise, policy_noise, noise_clip, num_episodes, batch_size, start_timestep, update_frequency)
#     169     continue
#     171 states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)
# --> 173 q1, q2 = critic(states, actions)
#     175 with no_grad():
#     176     noise = torch.clamp(
#     177         torch.normal(mean=0, std=policy_noise, size=(action_dim,)),
#     178         -noise_clip,
#     179         noise_clip
#     180     )
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[7], line 5, in to_torch.<locals>.convert_and_execute(cls, *args, **kwargs)
#       3 args = [torch.as_tensor(arg).float() for arg in args]
#       4 kwargs = {key: torch.as_tensor(arg).float() for key, arg in kwargs.items()}
# ----> 5 return func(cls, *args, **kwargs)
#
# Cell In[7], line 76, in Critic.forward(self, state, action)
#      73 @to_torch
#      74 def forward(self, state: torch.Tensor, action: torch.Tensor):
#      75     cat = torch.cat([state, action], dim=-1)
# ---> 76     return self._q1(cat).flatten(), self._q2(cat).flatten()
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
######### Hyperparameters #########
env_name = "Walker2d-v2"
log_interval = 100           # print avg reward after interval
gamma = 0.99                # discount for future rewards
batch_size = 100            # num of transitions sampled from replay buffer
lr = 0.001
exploration_noise = 0.2 
polyak = 0.995              # target policy update parameter (1-tau)
policy_noise = 0.2          # target policy smoothing noise
noise_clip = 0.5
policy_delay = 2            # delayed policy updates parameter
max_episodes = 1000         # max num of episodes
max_timesteps = 5000        # max timesteps in one episode
directory = "/home/imnotrachit/Documents/Collage_stuff/sem_6/rl/endsem/td3/preTrained/" # save trained models
filename = "TD3_{}".format(env_name)
###################################

env = gym.make(env_name)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

policy = TD3(lr, state_dim, action_dim, max_action)
replay_buffer = ReplayBuffer()

rewards = []
times=[]
avg_reward=0

# training procedure:
for episode in range(1, max_episodes+1):
    start_time = time.time()
    state = env.reset()
    ep_reward=0
    for t in range(max_timesteps):
        # select action and add exploration noise:
        action = policy.select_action(state)
        action = action + np.random.normal(0, exploration_noise, size=env.action_space.shape[0])
        action = action.clip(env.action_space.low, env.action_space.high)
        
        # take action in env:
        next_state, reward, done, _ = env.step(action)
        replay_buffer.add((state, action, reward, next_state, float(done)))
        state = next_state
        
        avg_reward += reward
        ep_reward += reward
        
        # if episode is done then update policy:
        if done or t==(max_timesteps-1):
            policy.update(replay_buffer, t, batch_size, gamma, polyak, policy_noise, noise_clip, policy_delay)
            end_time = time.time()
            episode_time = end_time - start_time
            break
    
    # logging updates:
    rewards.append(ep_reward)
    times.append(episode_time)
        
    if episode % log_interval == 0:
        avg_reward = int(avg_reward / log_interval)
        print("Episode: {}\tAverage Reward: {}".format(episode, avg_reward))
        avg_reward = 0
        
name = filename + '_solved'
policy.save(directory, name)


plt.figure(figsize=(12, 6))
plt.plot(rewards)
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.title('Episode vs Reward')
plt.show()

# %%
np.save('td3_reward.npy',rewards)
np.save('td3_time.npy',times)
